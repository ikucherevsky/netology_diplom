# %%
import pandas as pd

# %%
fd_001_train = pd.read_csv('C:/Users/Игорь/Downloads/nasa-cmaps/CMaps/train_FD001.txt',header=None,sep=' ')
fd_001_test = pd.read_csv('C:/Users/Игорь/Downloads/nasa-cmaps/CMaps/test_FD001.txt',header=None,sep=' ')

# %%
fd_001_train.drop(columns=[26,27],inplace=True)
fd_001_test.drop(columns=[26,27],inplace=True)

# %%
columns = ['unit_number','time_in_cycles','setting_1','setting_2','TRA','T2','T24','T30','T50','P2','P15','P30','Nf',
           'Nc','epr','Ps30','phi','NRf','NRc','BPR','farB','htBleed','Nf_dmd','PCNfR_dmd','W31','W32' ]

# %%
fd_001_train.columns = columns
fd_001_test.columns = columns

# %%
fd_001_train.head()
# Out:
#    unit_number  time_in_cycles  setting_1  setting_2    TRA      T2     T24  \
# 0            1               1    -0.0007    -0.0004  100.0  518.67  641.82
# 1            1               2     0.0019    -0.0003  100.0  518.67  642.15
# 2            1               3    -0.0043     0.0003  100.0  518.67  642.35
# 3            1               4     0.0007     0.0000  100.0  518.67  642.35
# 4            1               5    -0.0019    -0.0002  100.0  518.67  642.37
#
#        T30      T50     P2  ...     phi      NRf      NRc     BPR  farB  \
# 0  1589.70  1400.60  14.62  ...  521.66  2388.02  8138.62  8.4195  0.03
# 1  1591.82  1403.14  14.62  ...  522.28  2388.07  8131.49  8.4318  0.03
# 2  1587.99  1404.20  14.62  ...  522.42  2388.03  8133.23  8.4178  0.03
# 3  1582.79  1401.87  14.62  ...  522.86  2388.08  8133.83  8.3682  0.03
# 4  1582.85  1406.22  14.62  ...  522.19  2388.04  8133.80  8.4294  0.03
#
#    htBleed  Nf_dmd  PCNfR_dmd    W31      W32
# 0      392    2388      100.0  39.06  23.4190
# 1      392    2388      100.0  39.00  23.4236
# 2      390    2388      100.0  38.95  23.3442
# 3      392    2388      100.0  38.88  23.3739
# 4      393    2388      100.0  38.90  23.4044
#
# [5 rows x 26 columns]

# %%
count = fd_001_train.groupby('unit_number').count().reset_index()

# %%
count.head()
# Out:
#    unit_number  time_in_cycles  setting_1  setting_2  TRA   T2  T24  T30  T50  \
# 0            1             192        192        192  192  192  192  192  192
# 1            2             287        287        287  287  287  287  287  287
# 2            3             179        179        179  179  179  179  179  179
# 3            4             189        189        189  189  189  189  189  189
# 4            5             269        269        269  269  269  269  269  269
#
#     P2  ...  phi  NRf  NRc  BPR  farB  htBleed  Nf_dmd  PCNfR_dmd  W31  W32
# 0  192  ...  192  192  192  192   192      192     192        192  192  192
# 1  287  ...  287  287  287  287   287      287     287        287  287  287
# 2  179  ...  179  179  179  179   179      179     179        179  179  179
# 3  189  ...  189  189  189  189   189      189     189        189  189  189
# 4  269  ...  269  269  269  269   269      269     269        269  269  269
#
# [5 rows x 26 columns]

# %%
count['time_in_cycles'].min()
# Out:
# 128

# %%
count['time_in_cycles'].max()
# Out:
# 362

# %%
count['time_in_cycles'].hist(bins = 45)

# %%
(362 - 128) / 5
# Out:
# 46.8

# %%
count[count['time_in_cycles'] > 240].sort_values('time_in_cycles', ascending = False)
# Out:
#     unit_number  time_in_cycles  setting_1  setting_2  TRA   T2  T24  T30  \
# 68           69             362        362        362  362  362  362  362
# 91           92             341        341        341  341  341  341  341
# 95           96             336        336        336  336  336  336  336
# 66           67             313        313        313  313  313  313  313
# 82           83             293        293        293  293  293  293  293
# 1             2             287        287        287  287  287  287  287
# 63           64             283        283        283  283  283  283  283
# 94           95             283        283        283  283  283  283  283
# 85           86             278        278        278  278  278  278  278
# 16           17             276        276        276  276  276  276  276
# 55           56             275        275        275  275  275  275  275
# 4             5             269        269        269  269  269  269  269
# 83           84             267        267        267  267  267  267  267
# 6             7             259        259        259  259  259  259  259
# 93           94             258        258        258  258  258  258  258
# 53           54             257        257        257  257  257  257  257
# 45           46             256        256        256  256  256  256  256
#
#     T50   P2  ...  phi  NRf  NRc  BPR  farB  htBleed  Nf_dmd  PCNfR_dmd  W31  \
# 68  362  362  ...  362  362  362  362   362      362     362        362  362
# 91  341  341  ...  341  341  341  341   341      341     341        341  341
# 95  336  336  ...  336  336  336  336   336      336     336        336  336
# 66  313  313  ...  313  313  313  313   313      313     313        313  313
# 82  293  293  ...  293  293  293  293   293      293     293        293  293
# 1   287  287  ...  287  287  287  287   287      287     287        287  287
# 63  283  283  ...  283  283  283  283   283      283     283        283  283
# 94  283  283  ...  283  283  283  283   283      283     283        283  283
# 85  278  278  ...  278  278  278  278   278      278     278        278  278
# 16  276  276  ...  276  276  276  276   276      276     276        276  276
# 55  275  275  ...  275  275  275  275   275      275     275        275  275
# 4   269  269  ...  269  269  269  269   269      269     269        269  269
# 83  267  267  ...  267  267  267  267   267      267     267        267  267
# 6   259  259  ...  259  259  259  259   259      259     259        259  259
# 93  258  258  ...  258  258  258  258   258      258     258        258  258
# 53  257  257  ...  257  257  257  257   257      257     257        257  257
# 45  256  256  ...  256  256  256  256   256      256     256        256  256
#
#     W32
# 68  362
# 91  341
# 95  336
# 66  313
# 82  293
# 1   287
# 63  283
# 94  283
# 85  278
# 16  276
# 55  275
# 4   269
# 83  267
# 6   259
# 93  258
# 53  257
# 45  256
#
# [17 rows x 26 columns]

# %% [markdown]
# ## Так как классы в обучающей выборке распределены неравномерно, каждому классу, начиная от минимального количества циклов до поломки (в fd_001_train это соответствует 128 ) будем относить по 5 двигателей, число циклов до поломки каждого класса будет определяться как среднее арифметическое 5 реализаций жизенного цикла в отсортированном исходном наборе fd_001_train

# %%
sorted_data = count.sort_values('time_in_cycles', ascending = True).reset_index()

# %%
sorted_data.head()
# Out:
#    index  unit_number  time_in_cycles  setting_1  setting_2  TRA   T2  T24  \
# 0     38           39             128        128        128  128  128  128
# 1     90           91             135        135        135  135  135  135
# 2     69           70             137        137        137  137  137  137
# 3     56           57             137        137        137  137  137  137
# 4     57           58             147        147        147  147  147  147
#
#    T30  T50  ...  phi  NRf  NRc  BPR  farB  htBleed  Nf_dmd  PCNfR_dmd  W31  \
# 0  128  128  ...  128  128  128  128   128      128     128        128  128
# 1  135  135  ...  135  135  135  135   135      135     135        135  135
# 2  137  137  ...  137  137  137  137   137      137     137        137  137
# 3  137  137  ...  137  137  137  137   137      137     137        137  137
# 4  147  147  ...  147  147  147  147   147      147     147        147  147
#
#    W32
# 0  128
# 1  135
# 2  137
# 3  137
# 4  147
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Разбиение на классы fd_001_train

# %%
classes = {}

# %%
for i in range(0,len(sorted_data),5):
    classes[int(i/5) + 1] = [sorted_data['unit_number'][i],sorted_data['unit_number'][i+1],sorted_data['unit_number'][i+2],
                  sorted_data['unit_number'][i+3],sorted_data['unit_number'][i+4]]

# %%
classes
# Out:
# {1: [39, 91, 70, 57, 58],
#  2: [24, 8, 65, 90, 77],
#  3: [93, 27, 98, 45, 19],
#  4: [36, 13, 29, 28, 74],
#  5: [23, 37, 12, 60, 63],
#  6: [87, 3, 62, 14, 35],
#  7: [99, 61, 80, 40, 6],
#  8: [85, 4, 32, 44, 1],
#  9: [55, 30, 38, 18, 21],
#  10: [53, 34, 42, 50, 26],
#  11: [68, 79, 33, 100, 9],
#  12: [66, 22, 97, 15, 43],
#  13: [71, 16, 76, 73, 52],
#  14: [51, 72, 88, 47, 82],
#  15: [49, 41, 89, 10, 75],
#  16: [25, 59, 48, 78, 20],
#  17: [31, 81, 11, 46, 54],
#  18: [94, 7, 84, 5, 56],
#  19: [17, 86, 95, 64, 2],
#  20: [83, 67, 96, 92, 69]}

# %%
def data_classificator(x):
    for class_number in classes:
        if x['unit_number'] in classes[class_number]:
            return class_number
    return 'Class not found'

# %%
fd_001_train['Class_number'] = fd_001_train.apply(data_classificator,axis=1)

# %%
# проверка правильности разбиения на классы
fd_001_train[fd_001_train['Class_number'] == 19].groupby('unit_number').count()
# Out:
#              time_in_cycles  setting_1  setting_2  TRA   T2  T24  T30  T50  \
# unit_number
# 2                       287        287        287  287  287  287  287  287
# 17                      276        276        276  276  276  276  276  276
# 64                      283        283        283  283  283  283  283  283
# 86                      278        278        278  278  278  278  278  278
# 95                      283        283        283  283  283  283  283  283
#
#               P2  P15  ...  NRf  NRc  BPR  farB  htBleed  Nf_dmd  PCNfR_dmd  \
# unit_number            ...
# 2            287  287  ...  287  287  287   287      287     287        287
# 17           276  276  ...  276  276  276   276      276     276        276
# 64           283  283  ...  283  283  283   283      283     283        283
# 86           278  278  ...  278  278  278   278      278     278        278
# 95           283  283  ...  283  283  283   283      283     283        283
#
#              W31  W32  Class_number
# unit_number
# 2            287  287           287
# 17           276  276           276
# 64           283  283           283
# 86           278  278           278
# 95           283  283           283
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Оценим длину жизненного цикла в тестовых данных

# %%
test_count = fd_001_test.groupby('unit_number').count()

# %%
test_count.head()
# Out:
#              time_in_cycles  setting_1  setting_2  TRA   T2  T24  T30  T50  \
# unit_number
# 1                        31         31         31   31   31   31   31   31
# 2                        49         49         49   49   49   49   49   49
# 3                       126        126        126  126  126  126  126  126
# 4                       106        106        106  106  106  106  106  106
# 5                        98         98         98   98   98   98   98   98
#
#               P2  P15  ...  phi  NRf  NRc  BPR  farB  htBleed  Nf_dmd  \
# unit_number            ...
# 1             31   31  ...   31   31   31   31    31       31      31
# 2             49   49  ...   49   49   49   49    49       49      49
# 3            126  126  ...  126  126  126  126   126      126     126
# 4            106  106  ...  106  106  106  106   106      106     106
# 5             98   98  ...   98   98   98   98    98       98      98
#
#              PCNfR_dmd  W31  W32
# unit_number
# 1                   31   31   31
# 2                   49   49   49
# 3                  126  126  126
# 4                  106  106  106
# 5                   98   98   98
#
# [5 rows x 25 columns]

# %%
test_count.sort_values('time_in_cycles')
# Out:
#              time_in_cycles  setting_1  setting_2  TRA   T2  T24  T30  T50  \
# unit_number
# 1                        31         31         31   31   31   31   31   31
# 85                       34         34         34   34   34   34   34   34
# 39                       37         37         37   37   37   37   37   37
# 22                       39         39         39   39   39   39   39   39
# 14                       46         46         46   46   46   46   46   46
# ...                     ...        ...        ...  ...  ...  ...  ...  ...
# 12                      217        217        217  217  217  217  217  217
# 62                      232        232        232  232  232  232  232  232
# 91                      234        234        234  234  234  234  234  234
# 93                      244        244        244  244  244  244  244  244
# 49                      303        303        303  303  303  303  303  303
#
#               P2  P15  ...  phi  NRf  NRc  BPR  farB  htBleed  Nf_dmd  \
# unit_number            ...
# 1             31   31  ...   31   31   31   31    31       31      31
# 85            34   34  ...   34   34   34   34    34       34      34
# 39            37   37  ...   37   37   37   37    37       37      37
# 22            39   39  ...   39   39   39   39    39       39      39
# 14            46   46  ...   46   46   46   46    46       46      46
# ...          ...  ...  ...  ...  ...  ...  ...   ...      ...     ...
# 12           217  217  ...  217  217  217  217   217      217     217
# 62           232  232  ...  232  232  232  232   232      232     232
# 91           234  234  ...  234  234  234  234   234      234     234
# 93           244  244  ...  244  244  244  244   244      244     244
# 49           303  303  ...  303  303  303  303   303      303     303
#
#              PCNfR_dmd  W31  W32
# unit_number
# 1                   31   31   31
# 85                  34   34   34
# 39                  37   37   37
# 22                  39   39   39
# 14                  46   46   46
# ...                ...  ...  ...
# 12                 217  217  217
# 62                 232  232  232
# 91                 234  234  234
# 93                 244  244  244
# 49                 303  303  303
#
# [100 rows x 25 columns]

# %%
test_count['time_in_cycles'].hist()
